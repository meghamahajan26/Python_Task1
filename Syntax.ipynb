# %%
1. Markdown Cells
# Title of the Project

2. Headings in Markdown
# Main Title
## Subsection Title
### Subsubsection Title

3. Bold and Italics
**This is bold text.**
*This is italic text.*

4. Bullet Points
- Point one
- Point two
- Point three

5. Numbered Lists
1. First step
2. Second step
3. Third step

6. Hyperlinks
[Python Documentation](https://www.python.org/doc/)

7. Images
![Alt Text](https://example.com/image.jpg)

8. Tables
| Column 1 | Column 2 | Column 3 |
|----------|----------|----------|
| Value 1  | Value 2  | Value 3  |

9. Blockquotes
For quoting important information or highlighting notes.
> This is a blockquote, often used for emphasizing information.

10. Print
print("abc")

11. LaTeX for Math Equations
For documenting mathematical formulas, you can use LaTeX in markdown.
Inline equation: \( a^2 + b^2 = c^2 \)

12. Code Comments
In code cells, use comments (#) to describe what the code does.
# This line adds two numbers
result = 5 + 3

13.  Magic Commands
Use Jupyter's magic commands to include interactive elements or environmental information.
# %matplotlib inline  # To show Matplotlib plots inline
# %timeit some_function()  # Time the execution of code

14. Interactive Widgets (ipywidgets)
You can add interactive widgets for users to manipulate.
import ipywidgets as widgets
widgets.IntSlider()

15. HTML in Markdown
You can also use HTML elements for more control over formatting.
<p style="color:blue;">This is blue text.</p>
